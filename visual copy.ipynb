# %%
from stable_baselines3 import PPO

# ID del run salvato su WandB
run_id = "3d9olif2"  # Sostituisci con l'ID del tuo run salvato

# Percorso del modello
model_path = f"models/{run_id}/model.zip"

# Carica il modello
loaded_model = PPO.load(model_path)
# Out:
# c:\Users\iacop\anaconda3\envs\rl_ENV\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
#Enviroment set up
import wandb
from stable_baselines3 import PPO
from Reinforcement_Learning.test_env2 import TestEnvironment2
from wandb.integration.sb3 import WandbCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder

env = TestEnvironment2((224, 224), 15, "data_new/data_new", render_mode = 'human')
# Out:
# c:\Users\iacop\OneDrive - TUM\Desktop\Programmazione\Github\tum-adlr-11\Reinforcement_Learning\test_env2.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.unet = torch.load("Reinforcement_Learning/saved_models/model_full_old.pth", map_location=self.device)

# %%
num_episodes = 5
counter = 0

print(f"Starting environment rendering for {num_episodes} episodes...")
obs, info = env.reset()
env.render()
while counter < num_episodes:
    # Get action from the model based on the current observation
    action, _ = loaded_model.predict(obs, deterministic=False)
    obs, reward, done, truncated, info = env.step(action)

    env.render()  # Render the environment for visualization

    # Provide feedback to the user
    print(f"Episode {counter + 1}:")
    print(f"  Action Taken: {action}")
    print(f"  Reward Received: {reward}")
    print(f"  Done: {done}, Truncated: {truncated}")

    if done or truncated:
        print(f"Episode {counter + 1} finished. Resetting environment...")
        counter += 1
        obs, info = env.reset()
        env.render()

print("All episodes completed. Exiting...")

env.close()
# Out:
# Starting environment rendering for 5 episodes...
# Curren loss : -2
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.0874491  0.31193116]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.48986745 0.05722333]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.506095   -0.02248418]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.512474   -0.04751597]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.511495   -0.04233088]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.48885164 0.02157873]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.535308   0.00253688]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.5019035  0.01511178]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.52042294 -0.03012114]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.5064166  0.01050775]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.5133132  -0.02226307]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.49587786 -0.04641972]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [0.55424964 0.00074641]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.56464225 -0.01344033]
#   Reward Received: -0.08523477613925934
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0852, device='cuda:0')
# Episode 1:
#   Action Taken: [ 0.47593153 -0.02222758]
#   Reward Received: -0.08523477613925934
#   Done: True, Truncated: False
# Episode 1 finished. Resetting environment...
# Curren loss : -2
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [0.09862183 0.2943174 ]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.46934754 -0.10641244]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.49895293 -0.09634284]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.5064417  -0.09067742]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.48821035 -0.09866918]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.4459979  -0.05203652]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.47607642 -0.12160519]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.4523222  -0.05823584]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.5176773  -0.04458068]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.45904583 -0.08677918]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.46504885 -0.15559268]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.48242965 -0.07032148]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.48446822 -0.05260346]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.49240908 -0.08210286]
#   Reward Received: -0.0386200025677681
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0386, device='cuda:0')
# Episode 2:
#   Action Taken: [ 0.4779522  -0.13912922]
#   Reward Received: -0.0386200025677681
#   Done: True, Truncated: False
# Episode 2 finished. Resetting environment...
# Curren loss : -2
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [0.133469   0.31011683]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.47397032 -0.08047741]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.4314287 -0.0368808]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.44204077 -0.03119315]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.46377864 -0.10347082]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.45657545 -0.13696279]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.49227914 -0.10021257]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.4577406  -0.07690136]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.49248564 -0.06685291]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.46566755 -0.0612319 ]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.48692656 -0.08807711]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.43186867 -0.0546916 ]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.48402664 -0.11257721]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.46950412 -0.08893887]
#   Reward Received: -0.05147534981369972
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0515, device='cuda:0')
# Episode 3:
#   Action Taken: [ 0.5167454  -0.06060823]
#   Reward Received: -0.05147534981369972
#   Done: True, Truncated: False
# Episode 3 finished. Resetting environment...
# Curren loss : -2
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.12035683 0.362879  ]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.45691144 0.0629214 ]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.46129748 0.06532939]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.43078163 0.02286978]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.45216405 0.05312648]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.46256286 0.0549059 ]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.4615269  0.04066543]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.47582674 0.05657022]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.43860388 0.05240819]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [ 0.4767051  -0.00807667]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.48180377 0.05695997]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.4854144  0.06281435]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.45549926 0.02258011]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.46181455 0.04494429]
#   Reward Received: -0.04370729252696037
#   Done: False, Truncated: False
# Curren loss : tensor(-0.0437, device='cuda:0')
# Episode 4:
#   Action Taken: [0.4657241  0.04764254]
#   Reward Received: -0.04370729252696037
#   Done: True, Truncated: False
# Episode 4 finished. Resetting environment...
# Curren loss : -2
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [0.13987593 0.27173576]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5543017  -0.08415815]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5254691  -0.07841828]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5475802  -0.07897949]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.4852454  -0.06328348]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5081928  -0.07675709]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.522253   -0.11384256]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5076257  -0.08106434]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.53840226 -0.08188416]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5434084  -0.10948209]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.534778   -0.09996446]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5561048  -0.04434371]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5276585 -0.065549 ]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5406965  -0.07401756]
#   Reward Received: -0.14213550090789795
#   Done: False, Truncated: False
# Curren loss : tensor(-0.1421, device='cuda:0')
# Episode 5:
#   Action Taken: [ 0.5341543  -0.07002605]
#   Reward Received: -0.14213550090789795
#   Done: True, Truncated: False
# Episode 5 finished. Resetting environment...
# Curren loss : -2
# All episodes completed. Exiting...
