# %%
from stable_baselines3 import PPO
import os
# ID del run salvato su WandB
run_id = "20.01"  # Sostituisci con l'ID del tuo run salvato
current_path = os.getcwd()
parent_path = os.path.abspath(os.path.join(current_path, os.pardir))
# Percorso del modello
model_path = os.path.join(parent_path,f"models/{run_id}/model.zip")

# Carica il modello
loaded_model = PPO.load(model_path)
# Out:
# c:\Users\iacop\anaconda3\envs\rl_ENV\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
import wandb
from stable_baselines3 import PPO
from test_env2 import TestEnvironment2, VideoLoggingCallback
from wandb.integration.sb3 import WandbCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import ProgressBarCallback
from stable_baselines3.common.callbacks import CallbackList
import sys
import os


current_path = os.getcwd()
parent_path = os.path.abspath(os.path.join(current_path, os.pardir))
data_path = os.path.join(parent_path, "data_new/data_new")



env = TestEnvironment2((224, 224), 15, data_path, render_mode = 'human', wand= False)
# Out:
# c:\Users\iacop\OneDrive - TUM\Desktop\Programmazione\Github\tum-adlr-11\Reinforcement_Learning\test_env2.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.unet = torch.load("saved_models/model_full_old.pth", map_location=self.device)

# %%
num_episodes = 5
counter = 0

print(f"Starting environment rendering for {num_episodes} episodes...")
obs, info = env.reset()
env.render()
while counter < num_episodes:
    # Get action from the model based on the current observation
    action, _ = loaded_model.predict(obs, deterministic=False)
    obs, reward, done, truncated, info = env.step(action)

    env.render()  # Render the environment for visualization

    # Provide feedback to the user
    print(f"Episode {counter + 1}:")
    print(f"  Action Taken: {action}")
    print(f"  Reward Received: {reward}")
    print(f"  Done: {done}, Truncated: {truncated}")

    if done or truncated:
        print(f"Episode {counter + 1} finished. Resetting environment...")
        counter += 1
        obs, info = env.reset()
        env.render()

print("All episodes completed. Exiting...")

env.close()
# Out:
# Starting environment rendering for 5 episodes...
# Curren loss : tensor(0.0656, device='cuda:0')
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.004374599549919367
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.008749199099838734
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.013123799115419388
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.017498398199677467
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.021872997283935547
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-0.89376426 -1.        ]
#   Reward Received: -0.026247596368193626
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.030622195452451706
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.034996796399354935
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.03937139734625816
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04374599829316139
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04812059924006462
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05249520018696785
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05686980113387108
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06124440208077431
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 1:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06561899930238724
#   Done: True, Truncated: False
# Episode 1 finished. Resetting environment...
# Curren loss : tensor(0.0656, device='cuda:0')
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.004374599549919367
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.008749199099838734
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.013123799115419388
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.017498398199677467
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.021872997283935547
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.026247596368193626
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.030622195452451706
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.034996796399354935
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.03937139734625816
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04374599829316139
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04812059924006462
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05249520018696785
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05686980113387108
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06124440208077431
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 2:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06561899930238724
#   Done: True, Truncated: False
# Episode 2 finished. Resetting environment...
# Curren loss : tensor(0.0656, device='cuda:0')
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.004374599549919367
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.008749199099838734
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.013123799115419388
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.017498398199677467
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.021872997283935547
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.026247596368193626
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.030622195452451706
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.034996796399354935
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.03937139734625816
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04374599829316139
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04812059924006462
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05249520018696785
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05686980113387108
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06124440208077431
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 3:
#   Action Taken: [-0.98083377 -1.        ]
#   Reward Received: -0.06561899930238724
#   Done: True, Truncated: False
# Episode 3 finished. Resetting environment...
# Curren loss : tensor(0.0656, device='cuda:0')
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.004374599549919367
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.008749199099838734
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.013123799115419388
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-0.80840904 -1.        ]
#   Reward Received: -0.017498398199677467
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.021872997283935547
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.026247596368193626
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.030622195452451706
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.034996796399354935
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.03937139734625816
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04374599829316139
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04812059924006462
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05249520018696785
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05686980113387108
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06124440208077431
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 4:
#   Action Taken: [-0.92405146 -1.        ]
#   Reward Received: -0.06561899930238724
#   Done: True, Truncated: False
# Episode 4 finished. Resetting environment...
# Curren loss : tensor(0.0656, device='cuda:0')
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.004374599549919367
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.008749199099838734
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.013123799115419388
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.017498398199677467
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.021872997283935547
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.026247596368193626
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.030622195452451706
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.034996796399354935
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.03937139734625816
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04374599829316139
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.04812059924006462
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05249520018696785
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.05686980113387108
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06124440208077431
#   Done: False, Truncated: False
# Curren loss : tensor(0.0656, device='cuda:0')
# Episode 5:
#   Action Taken: [-1. -1.]
#   Reward Received: -0.06561899930238724
#   Done: True, Truncated: False
# Episode 5 finished. Resetting environment...
# Curren loss : tensor(0.0656, device='cuda:0')
# All episodes completed. Exiting...
